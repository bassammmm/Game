# %%
from IPython.display import clear_output
import time
print("                                                 Amen at your service :)\n")
print("\n                 .....................                                          ...................                  "
      "\n        .....................................                           .....................................        "
      "\n     ........                              ........                ........                            ........      "
      "\n  .......                                       .....            ....                                       .....    "
      "\n               .........................                                      .........................              "
      "\n        ......................................                         ......................................        "
      "\n     ...................         .................                  ...................         .................    "
      "\n   ..................       .      .................              ..................       .      .................  "
      "\n ...................       ...      .................           ...................       ...      ................. "
      "\n   ..................              ................               ..................              ................   "
      "\n     ...................         ................                   ...................         ................     "
      "\n         ....................................                           ....................................         "
      "\n                .......................                                        .......................               "
      "\n                                                                                                                     ")
time.sleep(3)
clear_output()

from IPython.display import clear_output
import time


#This is the main screen of Amen with all the options
def main_menu():
    print("\n                 .....................                                          ...................                  "
      "\n        .....................................                           .....................................        "
      "\n     ........                              ........                ........                            ........      "
      "\n  .......                                       .....            ....                                       .....    "
      "\n               .........................                                      .........................              "
      "\n        ......................................                         ......................................        "
      "\n     ...................         .................                  ...................         .................    "
      "\n   ..................       .      .................              ..................       .      .................  "
      "\n ...................       ...      .................           ...................       ...      ................. "
      "\n   ..................              ................               ..................              ................   "
      "\n     ...................         ................                   ...................         ................     "
      "\n         ....................................                           ....................................         "
      "\n                .......................                                        .......................               "
      "\n                                                                                                                     ")

    userinput = input("\nWhat do you want to do?")
    if (userinput=='a'):
        clear_output()
        time.sleep(1)
        
        print("\nOkay, lets play a game!")
        
        game()
            
            
    elif (userinput=='b'):
        print("\nPheww. Finally I can go charge myself now. ")
        
        time.sleep(3)
        clear_output()
        
    else:
        
        clear_output()
        user_input_bool = input("\nI didnt't get you, for a list of commands press 'h' or else to try again press 't'. ")
        if user_input_bool == 'h':
            clear_output()
            time.sleep(1)
            print("\nHelp Menu\n\nPress 'a' to Play a Game.\nPress 'b' to Quit.")
            time.sleep(1)
            
            
            main_menu() 
            
            
        else:
            clear_output()
            main_menu() 
    
    
    return;

#This is the game menu of Amen
def game():
    time.sleep(3)
    clear_output()
    
    
    user_input_game = input("\n1.Guess the number\n2.Predict your Death Age\n\nWhich game do you want to play? Press the corresponding number or press 'm' to go back to main screen.")
                            
    if user_input_game == '1':
        
        
        guess_number_game()
        
        
    elif user_input_game == '2':
        
        death_age_game()
        
    elif user_input_game == 'm':
        clear_output()
        main_menu()
        
        
    else:
        print("\nInvalid Input! Please enter the corresponding number of the game to play the game or press 'm' to return to menu.")
        game()
    
    
    return;  

#This is the 1st game in Game menu
def guess_number_game():
    import time
    time.sleep(1.5)
    clear_output()
    
    import time
    print("\n\n              GUESS THE NUMBER\n\nYou are advised to not play this game as you might end up wondering what the hell just happened.")
    time.sleep(4)
    
    user_input_guess_game = input("\n\nThink of a whole number between 1-10.\nPress 'y' when done.")
    while user_input_guess_game!='y':
        print("\nPlease enter only 'y' when done and NOT the number that you are thinking of!")
        import time
        time.sleep(1)
        user_input_guess_game = input("\n\nThink of a whole number between 1-10.\nPress 'y' when done.")
    if user_input_guess_game == 'y':
        user_input_guess_game = input("\n\nMultiply your number by 2.\nPress 'y' when done.")
        while user_input_guess_game!='y':
            print("\nPlease enter only 'y' when done and NOT the number that you are thinking of!")
            import time
            time.sleep(1)
            user_input_guess_game = input("\n\nMultiply your number by 2.\nPress 'y' when done.")
        if user_input_guess_game == 'y':
            user_input_guess_game = input("\n\nMultiply your new number by 5.\nPress 'y' when done.")
            while user_input_guess_game!='y':
                print("\nPlease enter only 'y' when done and NOT the number that you are thinking of!")
                import time
                time.sleep(1)
                user_input_guess_game = input("\n\nMultiply your new number by 5.\nPress 'y' when done.")
            if user_input_guess_game == 'y':
                user_input_guess_game = input("\n\nDivide this current number with you Original number.\nPress 'y' when done.")
                while user_input_guess_game!='y':
                    print("\nPlease enter only 'y' when done and NOT the number that you are thinking of!")
                    import time
                    time.sleep(1)
                    user_input_guess_game = input("\n\nDivide this current number with you Original number.\nPress 'y' when done.")
                if user_input_guess_game == 'y':
                    user_input_guess_game = input("\n\nNow substract 7 from this number.And remember this number!\nPress 'y' when done.")
                    while user_input_guess_game!='y':
                        print("\nPlease enter only 'y' when done and NOT the number that you are thinking of!")
                        import time
                        time.sleep(1)
                        user_input_guess_game = input("\n\nNow substract 7 from this number.And remember this number!\nPress 'y' when done.")
                    if user_input_guess_game == 'y':
                        import time
                        time.sleep(1)
                        clear_output()
                        import time
                        def countdown(n) :
                            while n>0:
                             print(n,"...Hacking you Brain, Please wait.")
                             time.sleep(1)
                             n=n-1   
                             if n==0:
                                clear_output()
                                time.sleep(3)
                                print("\nAre you ready to be MIND FUCKED?!")
                                time.sleep(2)
                                print("\nTHE NUMBER THAT YOU HAVE IN YOUR MIND RIGHT NOW IS 3!")
                        countdown(10)
                        time.sleep(1)
                        user_input_game = input("\n\nPlease press 'p' to play again or 'g' to return to game menu or 'm' to return to main menu.")
                        if user_input_game == 'm':
                            clear_output()
                            
                            main_menu()
                        elif user_input_game == 'g':
                            clear_output()
                            
                            game()
                        elif user_input_game == 'p':
                            clear_output()
                            
                            guess_number_game()
        return;



#this is the death age game                
def death_age_game():
    import time
    clear_output()
    print("                                            DEATH AGE CALCULATOR")
    time.sleep(3)

    print("\nI know, being Amen, it's not my right to ask a human's judgement")
    time.sleep(4)
    print("\nBut do you really want to know when you will die?")
    time.sleep(3)
    death_game_age_func()
    return;
    
def death_game_age_func():   
    import time
    user_input_death_age = input("\n\nPress 'y' for yes and 'm' to get the hell out of here.")
    if user_input_death_age == 'y':
        time.sleep(1)
        clear_output()
        time.sleep(2)
        print("\n\nI warned you human.")
        time.sleep(4)
        clear_output()
        user_name =        input("\n\nPlease enter your First Name only           :")
        user_birth_year =  input("\nPlease enter your Year of Birth              :")
        user_father_name = input("\nPlease enter your Father's First Name only   :")
        user_death_age_1 = len(user_name)
        user_death_age_2 = len(user_father_name)
        if user_death_age_1 < 5:
            import random
            user_death_age_1 = user_death_age_1 + random.randint(1,4)
        if user_death_age_2 > 9:
            import random
            user_death_age_2 = user_death_age_2 - random.randint(1,8)
        elif user_death_age_2 > 17:
            import random
            user_death_age_2 = user_death_age_2 - random.randint(8,16)
        user_death_age_1 = str(user_death_age_1)
        user_death_age_2 = str(user_death_age_2)


        time.sleep(2)
        clear_output()
        import time
        def countdown(n) :
            while n>0:
             print(n,"...Calculating Your Death Age")
             time.sleep(1)
             n=n-1
             if n==0:
                clear_output()    
                time.sleep(3)
                print("\nYou asked for it and Amen Obeys. Don't regret now!")
                time.sleep(3)
                print("\nYou'll die at the age of",user_death_age_1 + user_death_age_2)
        countdown(10)
        time.sleep(1)
        user_input_game = input("\n\nPlease press 'p' to play again or 'g' to return to game menu or 'm' to return to main menu.")
        if user_input_game == 'm':
            clear_output()
                            
            main_menu()
        elif user_input_game == 'g':
            clear_output()
                            
            game()
        elif user_input_game == 'p':
            clear_output
            
            death_age_game()
        
    elif user_input_death_age == 'm':
        clear_output()
        main_menu()
    elif user_input_death_age == 'g':
        clear_output()
        game()
    else:
        print("\n\nInvalid input! Please press 'y' to go ahead and play the game or press 'm' to go to main menu or 'g' to go to game menu.")
        import time
        time.sleep(4)
        death_game_age_func()
        return;


    


main_menu()
# Out:
# 10 ...Hacking you Brain, Please wait.
# 9 ...Hacking you Brain, Please wait.
# 8 ...Hacking you Brain, Please wait.
# 7 ...Hacking you Brain, Please wait.
# 6 ...Hacking you Brain, Please wait.
# 5 ...Hacking you Brain, Please wait.
